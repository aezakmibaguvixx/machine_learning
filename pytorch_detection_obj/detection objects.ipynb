# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: YOLOv5 requirement "setuptools>=65.5.1" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2023-2-19 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# подгружаем предобученную модель ёло
# загрузка из торч файла с весовыми коэф

# %%
pip install gitpython ipython setuptools>=65.5.1

# %%
img_dir_path = '/content/gdrive/MyDrive/detection_objects'
img_files = []
for filename in os.listdir(img_dir_path):
    img_files.append(img_dir_path + '/' + filename)

img_files
# Out:
# ['/content/gdrive/MyDrive/detection_objects/5.jpg',
#  '/content/gdrive/MyDrive/detection_objects/2.jpg',
#  '/content/gdrive/MyDrive/detection_objects/3.jpg',
#  '/content/gdrive/MyDrive/detection_objects/7.jpg',
#  '/content/gdrive/MyDrive/detection_objects/1.jpg',
#  '/content/gdrive/MyDrive/detection_objects/6.jpg',
#  '/content/gdrive/MyDrive/detection_objects/4.jpg',
#  '/content/gdrive/MyDrive/detection_objects/8.jpg',
#  '/content/gdrive/MyDrive/detection_objects/9.jpg']

# %% [markdown]
# c  помощью функции дирлист проходимся по  позициям  и извлекаем имя файлов ,добавляем / чтобы получились пути к файлам

# %%
# %time
results = model(img_files)
results
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.54 µs
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/9: 1440x1920 1 train
# image 2/9: 768x1024 1 train
# image 3/9: 600x800 2 trucks
# image 4/9: 408x612 2 cars, 1 bus
# image 5/9: 247x343 1 truck
# image 6/9: 467x700 20 persons
# image 7/9: 507x760 1 person, 1 laptop
# image 8/9: 590x885 4 persons, 1 sports ball, 1 cell phone
# image 9/9: 533x800 1 person, 1 cell phone
# Speed: 118.9ms pre-process, 1018.8ms inference, 5.1ms NMS per image at shape (9, 3, 480, 640)

# %%
results.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
results.save()
# Out:
# Saved 9 images to runs/detect/exp

# %%
obj_count = len(results.pandas().xyxy)

print('count_obj', obj_count)
results.pandas().xyxy[7]
# Out:
# count_obj 9
#          xmin        ymin        xmax        ymax  confidence  class  \
# 0   70.187653  229.571335  155.946960  581.712097    0.857632      0
# 1  298.933258  283.239532  353.574463  380.688263    0.761961     67
# 2  306.979553   81.908318  676.394348  585.572510    0.691756      0
# 3  564.028748   13.522061  643.307739  136.515686    0.663541      0
# 4  490.438965   61.912941  883.155090  578.825500    0.382975      0
# 5  792.601868  525.628357  832.620544  587.828491    0.321021     32
#
#           name
# 0       person
# 1   cell phone
# 2       person
# 3       person
# 4       person
# 5  sports ball

# %%
# !git clone
# Out:
# fatal: You must specify a repository to clone.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recursive ...       alias of --recurse-submodules
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
# ...
